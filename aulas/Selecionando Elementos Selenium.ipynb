# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
navegador = webdriver.Chrome()

# %%
import os

arquivo = r"C:\Users\calaz\Desktop\Projetos\python-web-automation\Pagina Hashtag.html"
navegador.get(arquivo)

# %% [markdown]
# #### Selecionar pela tag
#
# - Vamos selecionar o título

# %%
from selenium.webdriver.common.by import By

titulo = navegador.find_element(By.TAG_NAME, 'h2').text
print(titulo)
# Out:
# TODOS OS CURSOS DA HASHTAG TREINAMENTOS

# %% [markdown]
# #### Selecionar pelo Partial Link Text (ou LINK_TEXT)
# - Quero conseguir pegar o número de whatsapp de contato

# %%
numero_whatsapp = navegador.find_element(By.PARTIAL_LINK_TEXT, 'WhatsApp').text
print(numero_whatsapp)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 numero_whatsapp = navegador.find_element(By.PARTIAL_LINK_TEXT, 'WhatsApp').text
#       2 print(numero_whatsapp)
#
# File c:\Users\calaz\Desktop\Projetos\python-web-automation\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:899, in WebDriver.find_element(self, by, value)
#     896         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     897     return elements[0]
# --> 899 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\calaz\Desktop\Projetos\python-web-automation\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:492, in WebDriver.execute(self, driver_command, params)
#     489 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     491 if response:
# --> 492     self.error_handler.check_response(response)
#     493     response["value"] = self._unwrap_value(response.get("value", None))
#     494     return response
#
# File c:\Users\calaz\Desktop\Projetos\python-web-automation\venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"partial link text","selector":"WhatsApp"}
#   (Session info: chrome=150.0.7871.115); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff623490d25+155a5]
# 	chromedriver!GetHandleVerifier [0x7ff623490d80+15600]
# 	chromedriver!(No symbol) [0x7ff622fe594d]
# 	chromedriver!(No symbol) [0x7ff6230408e9]
# 	chromedriver!(No symbol) [0x7ff623040bec]
# 	chromedriver!(No symbol) [0x7ff623091437]
# 	chromedriver!(No symbol) [0x7ff62308e01b]
# 	chromedriver!(No symbol) [0x7ff623032e6c]
# 	chromedriver!(No symbol) [0x7ff623033d93]
# 	chromedriver!GetHandleVerifier [0x7ff623a76431+5facb1]
# 	chromedriver!GetHandleVerifier [0x7ff623a70a9b+5f531b]
# 	chromedriver!GetHandleVerifier [0x7ff623a95865+61a0e5]
# 	chromedriver!GetHandleVerifier [0x7ff6234adace+3234e]
# 	chromedriver!GetHandleVerifier [0x7ff6234b661c+3ae9c]
# 	chromedriver!GetHandleVerifier [0x7ff62349ab74+1f3f4]
# 	chromedriver!GetHandleVerifier [0x7ff62349ad04+1f584]
# 	chromedriver!GetHandleVerifier [0x7ff62347d9d7+2257]
# 	KERNEL32!BaseThreadInitThunk [0x7ff8ff6ce957+17]
# 	ntdll!RtlUserThreadStart [0x7ff900c67c1c+2c]

# %% [markdown]
# #### Selecionar pelo name
# - Preencher o formulário

# %%
navegador.find_element(By.NAME, 'email').send_keys("pythonimpressionador@gmail.com")

# %% [markdown]
# #### Selecionar pelo CSS Selector
# - Parecido com o XPATH, acaba não usando tanto, mas caso queira, tem uma referência aqui:
# https://saucelabs.com/resources/articles/selenium-tips-css-selectors
